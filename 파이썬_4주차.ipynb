# %% [markdown]
# ### 레버리지 상품에 장기투자하면 안 되는 이유
#
# Volatility Tax로 인해 음의 복리 수익률을 얻기 때문
# https://en.wikipedia.org/wiki/Volatility_tax

# %% [markdown]
# ### 데이터를 통해 알아보기

# %%
# 라이브러리 설치
# %pip install pandas-datareader
# %pip install yfinance
# Out:
# Collecting pandas-datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 5.1 MB/s eta 0:00:00
# Collecting lxml (from pandas-datareader)
#   Downloading lxml-4.9.3-cp310-cp310-manylinux_2_28_x86_64.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 46.2 MB/s eta 0:00:0000:01:00:01
# Requirement already satisfied: pandas>=0.23 in /home/codespace/.local/lib/python3.10/site-packages (from pandas-datareader) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /home/codespace/.local/lib/python3.10/site-packages (from pandas-datareader) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=0.23->pandas-datareader) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=0.23->pandas-datareader) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=0.23->pandas-datareader) (1.25.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader) (2023.5.7)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)
# Installing collected packages: lxml, pandas-datareader
# Successfully installed lxml-4.9.3 pandas-datareader-0.10.0
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting yfinance
#   Downloading yfinance-0.2.28-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in /home/codespace/.local/lib/python3.10/site-packages (from yfinance) (1.25.0)
# Requirement already satisfied: requests>=2.31 in /home/codespace/.local/lib/python3.10/site-packages (from yfinance) (2.31.0)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in /opt/python/3.10.8/lib/python3.10/site-packages (from yfinance) (4.9.3)
# Collecting appdirs>=1.4.4 (from yfinance)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pytz>=2022.5 in /home/codespace/.local/lib/python3.10/site-packages (from yfinance) (2023.3)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.3.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/codespace/.local/lib/python3.10/site-packages (from yfinance) (4.12.2)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4.1)
# Requirement already satisfied: six>=1.9 in /home/codespace/.local/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /home/codespace/.local/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2023.5.7)
# Installing collected packages: multitasking, appdirs, html5lib, frozendict, yfinance
# Successfully installed appdirs-1.4.4 frozendict-2.3.8 html5lib-1.1 multitasking-0.0.11 yfinance-0.2.28
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# 라이브러리 import
import datetime
from pandas_datareader import data as pdr
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np

# %%
# 기간 설정

start = datetime.datetime(2018, 1, 1)
end = datetime.datetime(2023, 1, 1)
yf.pdr_override()

# %%
# SIVBQ == 실리콘밸리은행, TSLA == 테슬라
ticker = "SIVBQ"
df = pdr.get_data_yahoo(ticker, start, end)
#df = pdr.get_data_yahoo("TSLA", start, end)

df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02  235.889999  237.550003  233.350006  237.380005  237.380005
# 2018-01-03  236.960007  238.340393  234.354996  237.669998  237.669998
# 2018-01-04  239.570007  241.779999  238.179993  239.940002  239.940002
# 2018-01-05  241.860001  244.434998  240.050003  243.850006  243.850006
# 2018-01-08  243.889999  244.044998  241.160004  243.580002  243.580002
# ...                ...         ...         ...         ...         ...
# 2022-12-23  215.130005  216.970001  211.634995  216.850006  216.850006
# 2022-12-27  216.399994  219.309998  210.330002  216.110001  216.110001
# 2022-12-28  215.610001  217.809998  212.839996  216.449997  216.449997
# 2022-12-29  219.529999  236.479996  218.669998  234.630005  234.630005
# 2022-12-30  229.850006  235.000000  226.119995  230.139999  230.139999
#
#              Volume
# Date
# 2018-01-02   395968
# 2018-01-03   341874
# 2018-01-04   721871
# 2018-01-05   402884
# 2018-01-08   409217
# ...             ...
# 2022-12-23   332559
# 2022-12-27   485233
# 2022-12-28   480089
# 2022-12-29  1031536
# 2022-12-30   710176
#
# [1259 rows x 6 columns]

# %%
df_chg = df.pct_change().dropna()

# %%
df_chg
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2018-01-03  0.004536  0.003327  0.004307  0.001222   0.001222 -0.136612
# 2018-01-04  0.011015  0.014431  0.016321  0.009551   0.009551  1.111512
# 2018-01-05  0.009559  0.010981  0.007851  0.016296   0.016296 -0.441889
# 2018-01-08  0.008393 -0.001596  0.004624 -0.001107  -0.001107  0.015719
# 2018-01-09  0.007667  0.022148  0.015135  0.013589   0.013589 -0.268738
# ...              ...       ...       ...       ...        ...       ...
# 2022-12-23  0.006927  0.004584  0.020592  0.004866   0.004866 -0.591696
# 2022-12-27  0.005903  0.010785 -0.006166 -0.003413  -0.003413  0.459088
# 2022-12-28 -0.003651 -0.006840  0.011934  0.001573   0.001573 -0.010601
# 2022-12-29  0.018181  0.085717  0.027391  0.083992   0.083992  1.148635
# 2022-12-30  0.047010 -0.006258  0.034070 -0.019137  -0.019137 -0.311535
#
# [1258 rows x 6 columns]

# %%
# 수정종가만 가져오기
close_chg = df_chg['Adj Close']

# %%
# 레버리지 적용 (현재는 -1 Inverse)
# leverage rate를 변경해보세요! (2, 3 등)
leverage_rate = -1
1+close_chg*(leverage_rate)
# Out:
# Date
# 2018-01-03    0.998778
# 2018-01-04    0.990449
# 2018-01-05    0.983704
# 2018-01-08    1.001107
# 2018-01-09    0.986411
#                 ...
# 2022-12-23    0.995134
# 2022-12-27    1.003413
# 2022-12-28    0.998427
# 2022-12-29    0.916008
# 2022-12-30    1.019137
# Name: Adj Close, Length: 1258, dtype: float64

# %%
# 초기 ETF 자산 1000으로 가정
leverage_path = np.array([1000 for i in range(len(df.Close)-1)]) * np.cumproduct((1+close_chg*(leverage_rate)))

# %%
leverage_path = np.append(1000, leverage_path)

# %%
# 기초자산 가격 Path
plt.plot(df.Close)
plt.title(f'{ticker} Original Path')
# Out:
# Text(0.5, 1.0, 'SIVBQ Original Path')

# %%
# ETF 가격 Path

plt.plot(leverage_path)
plt.title(f'{ticker} {leverage_rate}X Leverage Path')
# Out:
# Text(0.5, 1.0, 'SIVBQ -1X Leverage Path')

# %%
print(f"no leverage 수익률은 {(df.Close[-1] - df.Close[0])/df.Close[0]*100}%, {leverage_rate}X 수익률은 {(leverage_path[-1] - leverage_path[0])/leverage_path[0] *100}% 입니다.")
# Out:
# no leverage 수익률은 -3.0499643374505108%, -1X 수익률은 -70.33680845793181% 입니다.

# %% [markdown]
# ### 데이터 가정 후 Volatility Tax 확인

# %%
import pandas as pd

# %%
df = pd.DataFrame([100, 101]*20)

df.columns = ['Close']

# %%
df_chg = df.pct_change().dropna()
df_chg
# Out:
#        Close
# 1   0.010000
# 2  -0.009901
# 3   0.010000
# 4  -0.009901
# 5   0.010000
# 6  -0.009901
# 7   0.010000
# 8  -0.009901
# 9   0.010000
# 10 -0.009901
# 11  0.010000
# 12 -0.009901
# 13  0.010000
# 14 -0.009901
# 15  0.010000
# 16 -0.009901
# 17  0.010000
# 18 -0.009901
# 19  0.010000
# 20 -0.009901
# 21  0.010000
# 22 -0.009901
# 23  0.010000
# 24 -0.009901
# 25  0.010000
# 26 -0.009901
# 27  0.010000
# 28 -0.009901
# 29  0.010000
# 30 -0.009901
# 31  0.010000
# 32 -0.009901
# 33  0.010000
# 34 -0.009901
# 35  0.010000
# 36 -0.009901
# 37  0.010000
# 38 -0.009901
# 39  0.010000

# %%
# leverage rate 설정
# 5나 10으로도 바꿔보세요!
leverage_rate = -1

# %%
leverage_path = np.array([100 for i in range(len(df.Close)-1)]) * np.cumproduct([1+df_chg*(leverage_rate)])
leverage_path = np.append(100, leverage_path)

# %%
# 기초자산의 Price Path (가정)
plt.plot(df.Close)
plt.title("Original Path")
# Out:
# Text(0.5, 1.0, 'Original Path')

# %%
# 기초자산의 -1X 인버스 상품의 Price Path
# Volatility Tax

plt.plot(leverage_path)
plt.title(f"{leverage_rate}X Path")
# Out:
# Text(0.5, 1.0, '-1X Path')

# %%
leverage_path
# Out:
# array([100.        ,  99.        ,  99.98019802,  98.98039604,
#         99.96039996,  98.96079596,  99.94060582,  98.94119976,
#         99.9208156 ,  98.92160745,  99.9010293 ,  98.90201901,
#         99.88124692,  98.88243445,  99.86146846,  98.86285377,
#         99.84169391,  98.84327697,  99.82192328,  98.82370404,
#         99.80215656,  98.80413499,  99.78239375,  98.78456982,
#         99.76263487,  98.76500852,  99.74287989,  98.74545109,
#         99.72312882,  98.72589753,  99.70338167,  98.70634785,
#         99.68363842,  98.68680204,  99.66389909,  98.6672601 ,
#         99.64416366,  98.64772203,  99.62443215,  98.62818783])

# %%
print(f"no leverage 수익률은 {(list(df.Close)[-1] - df.Close[0])/df.Close[0]*100}%, {leverage_rate}X 수익률은 {(leverage_path[-1] - leverage_path[0])/leverage_path[0] *100}% 입니다.")
# Out:
# no leverage 수익률은 1.0%, -1X 수익률은 -1.371812174539727% 입니다.

# %% [markdown]
# ### Volatility Tax 조정

# %%
# Volatility Tax 계산
vol_drag = np.std(df_chg * leverage_rate)
vol_drag = float(vol_drag)**2
vol_drag
# Out:
# /tmp/ipykernel_18297/2255542223.py:3: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   vol_drag = float(vol_drag)**2
# 9.894725485203055e-05

# %%
# Volatility Tax 조정
adj_chg = df_chg *leverage_rate + vol_drag

# %%
# np cumproduct를 이용한 price path 생성
df = np.array([100 for i in range(len(adj_chg.Close))]) * np.cumproduct((1+adj_chg.Close))

# %%
# Volatility Tax 조정 이후 인버스 상품 Price Path

plt.plot(df)

# %% [markdown]
# ### 과제
#
# 1. yfinance 모듈(Yahoo Finance)을 이용하여, [2001-01-04 ~ 2020-10-4] 기간 삼성전자(005930.KS)의 4배 레버리지 상품의 Stock Price Path를 그리시오.
#
# 2. 해당 기간 삼성전자의 총 수익률과 4배 레버리지 상품의 수익률을 출력하시오
#
# 3. 해당 기간 삼성전자의 수익률의 역사적 변동성과 4배 레버리지 상품의 수익률의 역사적 변동성을 출력하시오

# %%
# 1번 문제 (셀을 늘려도 괜찮습니다)

# %%
# 2번 문제

# %%
# 3번 문제
